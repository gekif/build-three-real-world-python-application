# %% [markdown]
# # Exploring Alpha Vantage API

# %% [markdown]
# ### Imports- **Run First**

# %%
#open file with yout API key
with open('Alpha_Vantage_API_key.txt') as file:
    API_key = file.read()

API_key = API_key.strip()

# %%
#import libraries
from alpha_vantage.timeseries import TimeSeries

import requests
from bs4 import BeautifulSoup

import pandas as pd
import io

# %%
#build TimeSeries variable from Alpha Vantage API
ts1 = TimeSeries(key = API_key)

# %% [markdown]
# ### Challenge: Analyze Microsoft Stock

# %%
#get monthly data of Microsoft using the alpha_vantage package
ts1.get_monthly('MSFT')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[8], line 2
#       1 #get monthly data of Microsoft using the alpha_vantage package
# ----> 2 ts1.get_monthly('MSFT')
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\alpha_vantage\alphavantage.py:218, in AlphaVantage._output_format.<locals>._format_wrapper(self, *args, **kwargs)
#     216 @wraps(func)
#     217 def _format_wrapper(self, *args, **kwargs):
# --> 218     call_response, data_key, meta_data_key = func(
#     219         self, *args, **kwargs)
#     220     if 'json' in self.output_format.lower() or 'pandas' \
#     221             in self.output_format.lower():
#     222         if data_key is not None:
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\alpha_vantage\alphavantage.py:160, in AlphaVantage._call_api_on_func.<locals>._call_wrapper(self, *args, **kwargs)
#     158 else:
#     159     url = '{}{}'.format(url, apikey_parameter)
# --> 160 return self._handle_api_call(url), data_key, meta_data_key
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\alpha_vantage\alphavantage.py:361, in AlphaVantage._handle_api_call(self, url)
#     359     raise ValueError(json_response["Error Message"])
#     360 elif "Information" in json_response and self.treat_info_as_error:
# --> 361     raise ValueError(json_response["Information"])
#     362 elif "Note" in json_response and self.treat_info_as_error:
#     363     raise ValueError(json_response["Note"])
#
# ValueError: We have detected your API key as BDRPQ7VJJ5EQ5V52 and our standard API rate limit is 25 requests per day. Please subscribe to any of the premium plans at https://www.alphavantage.co/premium/ to instantly remove all daily rate limits.

# %%
#get weekly data of Microsoft using the alpha_vantage package
ts1.get_weekly('MSFT')

# %%
#pull income statement for Microsoft with requests package
url = 'https://www.alphavantage.co/query?function=INCOME_STATEMENT&symbol=MSFT&apikey=' + str(API_key)
r = requests.get(url)
fd = BeautifulSoup(r.content)

print(fd)

# %%
#get Bollinger bands values for Microsoft with requests package, daily interval, 10 time periods, open stock value
url = 'https://www.alphavantage.co/query?function=BBANDS&symbol=MSFT&interval=daily&time_period=10&series_type=open&nbdevup=3&nbdevdn=3&apikey=' + \
    str(API_key)
r = requests.get(url)
ti = BeautifulSoup(r.content)

print(ti)
