# %% [markdown]
# # Exploring Alpha Vantage API

# %% [markdown]
# ### Imports- **Run First**

# %%
#open file with your API key
with open('Alpha_Vantage_API_key.txt') as file:
    API_key = file.read()

API_key = API_key.strip()

# %%
#import libraries
from alpha_vantage.timeseries import TimeSeries

import requests
from bs4 import BeautifulSoup

import pandas as pd
import io

# %%
#build TimeSeries variable from Alpha Vantage API
ts1 = TimeSeries(key = API_key)

# %% [markdown]
# ### How to put stock data into a DataFrame

# %% [markdown]
# #### Requests Method

# %%
#get weekly stock data of Apple in DataFrame format
url = f'https://www.alphavantage.co/query?function=TIME_SERIES_WEEKLY&symbol=AAPL&interval=5min&apikey={API_key}&datatype=csv'

r = requests.get(url).content
data = pd.read_csv(io.StringIO(r.decode('utf-8')))
print(data)
# Out:
#        timestamp     open     high      low   close     volume
# 0     2026-02-12  277.905  280.180  260.180  261.73  212008806
# 1     2026-02-06  260.030  280.905  259.205  278.12  331689378
# 2     2026-01-30  251.480  261.950  249.800  259.48  305741477
# 3     2026-01-23  252.730  254.790  243.420  248.04  213320034
# 4     2026-01-16  259.160  261.820  254.930  255.53  242545372
# ...          ...      ...      ...      ...     ...        ...
# 1366  1999-12-10  114.560  118.000   99.000  103.00   25152800
# 1367  1999-12-03   94.250  115.560   93.250  115.00   28046300
# 1368  1999-11-26   91.750   95.500   88.500   95.06    9757600
# 1369  1999-11-19   89.620   94.750   88.060   92.44   13711000
# 1370  1999-11-12   87.750   97.730   86.750   90.62   25776200
#
# [1371 rows x 6 columns]

# %%
#get head of data
data.head(10)
# Out:
#     timestamp     open     high      low   close     volume
# 0  2026-02-12  277.905  280.180  260.180  261.73  212008806
# 1  2026-02-06  260.030  280.905  259.205  278.12  331689378
# 2  2026-01-30  251.480  261.950  249.800  259.48  305741477
# 3  2026-01-23  252.730  254.790  243.420  248.04  213320034
# 4  2026-01-16  259.160  261.820  254.930  255.53  242545372
# 5  2026-01-09  270.640  271.510  255.700  259.37  236725388
# 6  2026-01-02  272.690  277.840  269.000  271.01  110986523
# 7  2025-12-26  272.860  275.430  269.560  273.40  105646202
# 8  2025-12-19  280.150  280.150  266.950  273.67  334459218
# 9  2025-12-12  278.130  280.030  273.810  278.28  173978918

# %% [markdown]
# #### Python Package Method

# %%
#store Apple stock intraday data in data and meta_data variables
apple1, meta_data = ts1.get_intraday("AAPL")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[40], line 2
#       1 #store Apple stock intraday data in data and meta_data variables
# ----> 2 apple1, meta_data = ts1.get_intraday("AAPL")
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\alpha_vantage\alphavantage.py:218, in AlphaVantage._output_format.<locals>._format_wrapper(self, *args, **kwargs)
#     216 @wraps(func)
#     217 def _format_wrapper(self, *args, **kwargs):
# --> 218     call_response, data_key, meta_data_key = func(
#     219         self, *args, **kwargs)
#     220     if 'json' in self.output_format.lower() or 'pandas' \
#     221             in self.output_format.lower():
#     222         if data_key is not None:
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\alpha_vantage\alphavantage.py:160, in AlphaVantage._call_api_on_func.<locals>._call_wrapper(self, *args, **kwargs)
#     158 else:
#     159     url = '{}{}'.format(url, apikey_parameter)
# --> 160 return self._handle_api_call(url), data_key, meta_data_key
#
# File ~\AppData\Local\Programs\Python\Python314\Lib\site-packages\alpha_vantage\alphavantage.py:361, in AlphaVantage._handle_api_call(self, url)
#     359     raise ValueError(json_response["Error Message"])
#     360 elif "Information" in json_response and self.treat_info_as_error:
# --> 361     raise ValueError(json_response["Information"])
#     362 elif "Note" in json_response and self.treat_info_as_error:
#     363     raise ValueError(json_response["Note"])
#
# ValueError: Thank you for using Alpha Vantage! This is a premium endpoint. You may subscribe to any of the premium plans at https://www.alphavantage.co/premium/ to instantly unlock all premium endpoints

# %%
#print meta_data
meta_data

# %%
#print data
apple1

# %%
#store data into a DataFrame
df_apple1 = pd.DataFrame(apple1).transpose().reset_index()
df_apple1.head()

# %%
#Bring in data in DataFrame format
ts2 = TimeSeries(key = API_key, output_format='pandas')

# %%
# display new intraday stock data
ts2.get_intraday("AAPL")

# %%
#get full amount of intraday stock data for data and meta_data
df_apple2, meta_data = ts2.get_intraday("AAPL", outputsize='full')

# %%
#print meta_data
meta_data

# %%
#print data with reset index
df_apple2.reset_index()
